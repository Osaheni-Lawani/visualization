# %% [markdown]
# Monthly Bike Share Ridership in Toronto Visualization file without code

# %% [markdown]
# ![monthly_ridership.png](attachment:monthly_ridership.png)

# %% [markdown]
# Bike Share Toronto Ridership Trend Visualization file without code

# %% [markdown]
# ![image.png](attachment:image.png)
